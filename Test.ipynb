# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdullahAlTalaq/About-Me/blob/main/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mplsoccer.pitch import Pitch
import seaborn as sns

# %%
data = pd.read_csv('events.csv')

filtered_df = data[data['Team'] == 'T']

# %%
# !pip install mplsoccer
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 2.0 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
from mplsoccer.pitch import Pitch

# Create a Pitch object
pitch = Pitch(pitch_type='statsbomb', pitch_color='#22312b', line_color='#c7d5cc')

# Create a figure
fig, ax = pitch.draw()

# Set the pitch's x and y limits
ax.set_xlim(0, 120)
ax.set_ylim(0, 80)

# Invert the y-axis to display the pitch in the correct orientation
ax.invert_yaxis()

# Simulated pass data (replace with your own data)
pass_data = {
    'x_start': 30,
    'y_start': 70,
    'x_end': 25,
    'y_end': 60
}

# Plot the pass as a green line
ax.plot([pass_data['x_start'], pass_data['x_end']], [pass_data['y_start'], pass_data['y_end']], color='green', linewidth=2)

# Plot the starting point as a red point
ax.scatter(pass_data['x_start'], pass_data['y_start'], color='green', s=100)

# Show the pitch with the pass and starting point
plt.show()

# %%
df.head()
filtered_df.shape
# Out:
# (63, 9)

# %%
import matplotlib.pyplot as plt
from mplsoccer.pitch import Pitch

# Create a Pitch object
pitch = Pitch(pitch_type='statsbomb', pitch_color='#22312b', line_color='#c7d5cc')

# Create a figure
fig, ax = plt.subplots(figsize=(13.5, 8))
fig.set_facecolor("#22312b")

# Set the pitch's x and y limits
ax.set_xlim(0, 120)
ax.set_ylim(0, 80)

# Display x-axis and y-axis
pitch.draw(ax=ax)

# Invert the y-axis to display the pitch in the correct orientation
ax.invert_yaxis()

# Simulated pass data (replace with your own data)
pass_data = {
    'x_start': 38,
    'y_start': 17,
    'x_end': 46,
    'y_end': 3
}
for index, row in df.iterrows():
    x_start = row['X']
    y_start = row['Y']
    x_end = row['X2']
    y_end= row['Y2']
# Plot the pass as a green line
    if row['Team']=='P':
      ax.plot([x_start, x_end], [y_start, y_end], color='green', linewidth=2)

# Plot the starting point as a red point
ax.scatter(df['X'], df['Y'], color='green', s=100)

# Add x-axis and y-axis labels with their values
ax.set_xticks([0, 60, 120])
ax.set_yticks([0, 40, 80])
ax.set_xticklabels(['0', '60', '120'])
ax.set_yticklabels(['0', '40', '80'])

# Show the pitch with the pass, starting point, and axes
plt.show()

# %%
import matplotlib.pyplot as plt
from mplsoccer.pitch import Pitch

# Create a Pitch object
#pitch = Pitch(pitch_type='statsbomb', pitch_color='#22312b', line_color='#c7d5cc')

# Create a figure
fig, ax = plt.subplots(figsize=(13.5, 8))
fig.set_facecolor("#22312b")

# Set the pitch's x and y limits
ax.set_xlim(0, 120)
ax.set_ylim(0, 80)

# Display x-axis and y-axis
pitch.draw(ax=ax)

# Invert the y-axis to display the pitch in the correct orientation
ax.invert_yaxis()

# Simulated pass data (replace with your own data)
pass_data = {
    'x_start': 60,
    'y_start': 40,
    'x_end': 25,
    'y_end': 60
}

# Plot the pass as a green line
ax.plot([pass_data['x_start'], pass_data['x_end']], [pass_data['y_start'], pass_data['y_end']], color='green', linewidth=2)

# Plot the starting point as a red point
ax.scatter(pass_data['x_start'], pass_data['y_start'], color='red', s=100)

# Show the pitch with the pass, starting point, and axes
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Arc
fig, ax = plt.subplots()
fig.set_size_inches(7, 5)

for i in range(len(data)):
    plt.plot([int(data["X"][i]),int(data["X2"][i])],
             [int(data["Y"][i]),int(data["Y2"][i])],
             color="blue")
    plt.plot(int(data["X"][i]),int(data["Y"][i]),"o", color="green")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-6e224740e22c> in <cell line: 8>()
#       7
#       8 for i in range(len(data)):
# ----> 9     plt.plot([int(data["X"][i]),int(data["X2"][i])],
#      10              [int(data["Y"][i]),int(data["Y2"][i])],
#      11              color="blue")
#
# ValueError: invalid literal for int() with base 10: '-'

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Arc

# Create figure
fig = plt.figure()
fig.set_size_inches(12, 10)  # Set the figure size to match x=120 and y=100

# Pitch Outline & Centre Line
plt.plot([0, 0], [0, 100], color="black")
plt.plot([0, 120], [100, 100], color="black")
plt.plot([120, 120], [100, 0], color="black")
plt.plot([120, 0], [0, 0], color="black")
plt.plot([60, 60], [0, 100], color="black")

# Left Penalty Area (Reduced Size)
plt.plot([16.5, 16.5], [80, 20], color="black")
plt.plot([0, 16.5], [80, 80], color="black")
plt.plot([16.5, 0], [20, 20], color="black")

# Right Penalty Area (Reduced Size)
plt.plot([120, 103.5], [80, 80], color="black")
plt.plot([103.5, 103.5], [80, 20], color="black")
plt.plot([103.5, 120], [20, 20], color="black")

# Left 6-yard Box (Reduced Size)
plt.plot([0, 6], [65, 65], color="black")
plt.plot([6, 6], [65, 35], color="black")
plt.plot([6, 0], [35, 35], color="black")

# Right 6-yard Box (Reduced Size)
plt.plot([120, 114], [65, 65], color="black")
plt.plot([114, 114], [65, 35], color="black")
plt.plot([114, 120], [35, 35], color="black")

# Prepare Circles
centreCircle = plt.Circle((60, 50), 7.32, color="black", fill=False)
centreSpot = plt.Circle((60, 50), 0.8, color="black")
leftPenSpot = plt.Circle((11, 50), 0.8, color="black")
rightPenSpot = plt.Circle((109, 50), 0.8, color="black")

# Draw Circles
fig.gca().add_patch(centreCircle)
fig.gca().add_patch(centreSpot)
fig.gca().add_patch(leftPenSpot)
fig.gca().add_patch(rightPenSpot)

# Prepare Arcs
leftArc = Arc((11, 50), height=18.3, width=18.3, angle=0, theta1=310, theta2=50, color="black")
rightArc = Arc((109, 50), height=18.3, width=18.3, angle=0, theta1=130, theta2=230, color="black")

# Draw Arcs
fig.gca().add_patch(leftArc)
fig.gca().add_patch(rightArc)

# Tidy Axes
plt.axis('off')




for i in range(len(data_T)):
    plt.plot([int(data_T["X"][i]), int(data_T["X2"][i])], [int(data_T["Y"][i]), int(data_T["Y2"][i])], color="blue")
    plt.plot(int(data_T["X"][i]), int(data_T["Y"][i]), "o", color="green")


#Display Pitch
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 9
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
data_T.head()
data_T.shape
# Out:
# (63, 9)
